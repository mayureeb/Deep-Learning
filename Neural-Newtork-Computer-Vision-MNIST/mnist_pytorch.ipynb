# %% [markdown]
# # Part 0: Initial setup
#
# To enable GPU:
# 1.   Click Edit -> Notebook settings
# 2.   Under Hardware Accelerator select GPU
# 3.   On the right side of this page, click connect to a hosted runtime
#
#
# If you ever see an error about needing third-party cookies enabled, you can disable blocking them or whitelist them.
# Here is a simple way to whitelist (in chrome)
#
# For old chrome:
# 1.   Goto chrome://settings/content/cookies>search=cookie
# 2.   Uncheck "Block third-party cookies" or
# 3.   Click Add next to Allow and type https://[*.]googleusercontent.com:443
#
# For new chrome:
# 1.   Goto settings and search "cookie"
# 2.   Click the "content settings" button
# 3.   Follow steps 2 or 3 from above
# ---

# %%
# This shows how to connect your google drive account with a colab instance. It's pretty easy.
# Load the Drive helper and mount
from google.colab import drive

# This will prompt4/dQBuNfrunSbHNn-Soxxq-DzybtopduPu2NrNoZ_R5HuCa64BnZ31F1o for authorization.
drive.mount('/gdrive')
# Create a directory and mount Google Drive using that directory.
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %% [markdown]
# # Drive not connecting after it seemed like it worked before?
# 1. First try restarting the runtime via Runtime -> Restart Runtime
# 2. Then try to run the above again.
# 3. If this still doesn't work, call Reset All Runtimes. This is the nuclear option that will delete all your data not saved on your personal drive account, and will erase everything you installed.

# %%
# Now let's test that Google Drive is up and running. 
# You may have to change "My Drive" if you have renamed it something else.
# !ls "/gdrive/My Drive"

with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat "/gdrive/My Drive/foo.txt"
# !rm "/gdrive/My Drive/foo.txt"

# %%
# This is code to download and install pytorch
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
  
import torch
print('Version', torch.__version__)
print('CUDA enabled:', torch.cuda.is_available())
  
# NOTE: This one takes a while the first time you run it, and you will likely see 
# tcmalloc: large alloc 1073750016 bytes == 0x5c54a000 @ or something similar.
# It should then print out:
# Version 0.4.1
# CUDA enabled: True
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x56ae0000 @  0x7f908ab682a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# Version 0.4.1
# CUDA enabled: True

# %%
# Define some useful save and restoring functions. 
# You can thank your TAs for providing this code, 
# it will probably be useful for you in the future as well.
import torch
import torch.nn as nn
import numpy as np
import os
import pdb
class pt_util(object):
    @staticmethod
    # This does more than the simple Pytorch restore. It checks that the names 
    # of variables match, and if they don't doesn't throw a fit. It is similar 
    # to how Caffe acts. This is especially useful if you decide to change your
    # network architecture but don't want to retrain from scratch.
    def restore(net, save_file):
        net_state_dict = net.state_dict()
        restore_state_dict = torch.load(save_file)

        restored_var_names = set()

        print('Restoring:')
        for var_name in restore_state_dict.keys():
            if var_name in net_state_dict:
                var_size = net_state_dict[var_name].size()
                restore_size = restore_state_dict[var_name].size()
                if var_size != restore_size:
                    print('Shape mismatch for var', var_name, 'expected', var_size, 'got', restore_size)
                else:
                    if isinstance(net_state_dict[var_name], torch.nn.Parameter):
                        # backwards compatibility for serialized parameters
                        net_state_dict[var_name] = restore_state_dict[var_name].data
                    try:
                        net_state_dict[var_name].copy_(restore_state_dict[var_name])
                        print(str(var_name) + ' -> \t' + str(var_size) + ' = ' + str(int(np.prod(var_size) * 4 / 10**6)) + 'MB')
                        restored_var_names.add(var_name)
                    except:
                        print('While copying the parameter named {}, whose dimensions in the model are'
                              ' {} and whose dimensions in the checkpoint are {}, ...'.format(
                                  var_name, var_size, restore_size))
                        raise

        ignored_var_names = sorted(list(set(restore_state_dict.keys()) - restored_var_names))
        unset_var_names = sorted(list(set(net_state_dict.keys()) - restored_var_names))
        print('')
        if len(ignored_var_names) == 0:
            print('Restored all variables')
        else:
            print('Did not restore:\n\t' + '\n\t'.join(ignored_var_names))
        if len(unset_var_names) == 0:
            print('No new variables')
        else:
            print('Initialized but did not modify:\n\t' + '\n\t'.join(unset_var_names))

        print('Restored %s' % save_file)
        
    @staticmethod
    def restore_latest(net, folder):
        import glob
        import re
        checkpoints = sorted(glob.glob(folder + '/*.pt'), key=os.path.getmtime)
        start_it = 0
        if len(checkpoints) > 0:
            pt_util.restore(net, checkpoints[-1])
            start_it = int(re.findall(r'\d+', checkpoints[-1])[-1])
        return start_it

    @staticmethod
    def save(net, file_name, num_to_keep=1):
        folder = os.path.dirname(file_name)
        if not os.path.exists(folder):
            os.makedirs(folder)
        torch.save(net.state_dict(), file_name)
        import glob
        extension = os.path.splitext(file_name)[1]
        checkpoints = sorted(glob.glob(folder + '/*' + extension), key=os.path.getmtime)
        print('Saved %s\n' % file_name)
        if num_to_keep > 0:
            for ff in checkpoints[:-num_to_keep]:
                os.remove(ff)

# %% [markdown]
# # Part 1: Implementing a network for MNIST

# %%
# This is where you define your network architecture.
# Note: The TAs know this follows the PyTorch MNIST tutorial available at 
# https://github.com/pytorch/examples/blob/master/mnist/main.py
# Where do you think we got it from? 
# So we are asking you to implement something slightly different. 
# You can use that as a guide, but make sure you understand what it all does.


import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
class MNISTNet(nn.Module):
    def __init__(self):
        super(MNISTNet, self).__init__()
        # The network should be as follows:
        # One fully connected layer with 1024 outputs.
        # One fully connected layer with 512 outputs.
        # Then the final classification layer.
        # All the nonlinearities should be ReLU.
        # These instructions are vague on purpose.
        self.fc1 = nn.Linear(28*28, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)
#         raise NotImplementedError('Define the layers here')

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)
#         raise NotImplementedError('Define the forward pass')
      
      
    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def loss(self, prediction, label, reduction='elementwise_mean'):
        # You should also use the cross_entropy loss rather than the NLL loss.
        l = nn.CrossEntropyLoss()
#         print(prediction.shape, label.shape)
        return l(prediction, label)
#         raise NotImplementedError('Define the loss here')


    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)


def train(model, device, train_loader, optimizer, epoch, log_interval):
    model.train()
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = model.loss(output, label)
        loss.backward()
        
#         raise NotImplementedError('Define the forward pass and loss here')
        
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(device), label.to(device)
            output = model(data)
            test_loss += model.loss(output, label).item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(label.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
# Play around with these constants, you may find a better setting.
BATCH_SIZE = 256
TEST_BATCH_SIZE = 1000
EPOCHS = 200
LEARNING_RATE = 0.01
MOMENTUM = 0.7
USE_CUDA = True
SEED = 1
LOG_INTERVAL = 100

# %%
# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=TEST_BATCH_SIZE, **kwargs)


model = MNISTNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
# This will save checkpoints in your Google Drive account.
start_epoch = model.load_last_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints')
try:
    for epoch in range(start_epoch, EPOCHS + 1):
#         pdb.set_trace()
        train(model, device, train_loader, optimizer, epoch, LOG_INTERVAL)
        test(model, device, test_loader)
        model.save_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints/%03d.pt' % epoch)
except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints/%03d.pt' % epoch)
# Out:
# Using device cuda
# num cpus: 2
# Restoring:
# fc1.weight -> 	torch.Size([1024, 784]) = 3MB
# fc1.bias -> 	torch.Size([1024]) = 0MB
# fc2.weight -> 	torch.Size([512, 1024]) = 2MB
# fc2.bias -> 	torch.Size([512]) = 0MB
# fc3.weight -> 	torch.Size([10, 512]) = 0MB
# fc3.bias -> 	torch.Size([10]) = 0MB
#
# Restored all variables
# No new variables
# Restored /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/110.pt
# Train Epoch: 110 [0/60000 (0%)]	Loss: 0.001028
# Train Epoch: 110 [25600/60000 (43%)]	Loss: 0.001078
# Train Epoch: 110 [51200/60000 (85%)]	Loss: 0.000636
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/110.pt
#
# Train Epoch: 111 [0/60000 (0%)]	Loss: 0.000755
# Train Epoch: 111 [25600/60000 (43%)]	Loss: 0.000657
# Train Epoch: 111 [51200/60000 (85%)]	Loss: 0.000296
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/111.pt
#
# Train Epoch: 112 [0/60000 (0%)]	Loss: 0.000651
# Train Epoch: 112 [25600/60000 (43%)]	Loss: 0.000467
# Train Epoch: 112 [51200/60000 (85%)]	Loss: 0.000453
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/112.pt
#
# Train Epoch: 113 [0/60000 (0%)]	Loss: 0.000715
# Train Epoch: 113 [25600/60000 (43%)]	Loss: 0.000841
# Train Epoch: 113 [51200/60000 (85%)]	Loss: 0.000410
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/113.pt
#
# Train Epoch: 114 [0/60000 (0%)]	Loss: 0.000658
# Train Epoch: 114 [25600/60000 (43%)]	Loss: 0.000877
# Train Epoch: 114 [51200/60000 (85%)]	Loss: 0.000574
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/114.pt
#
# Train Epoch: 115 [0/60000 (0%)]	Loss: 0.000656
# Train Epoch: 115 [25600/60000 (43%)]	Loss: 0.000733
# Train Epoch: 115 [51200/60000 (85%)]	Loss: 0.000770
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/115.pt
#
# Train Epoch: 116 [0/60000 (0%)]	Loss: 0.000746
# Train Epoch: 116 [25600/60000 (43%)]	Loss: 0.000778
# Train Epoch: 116 [51200/60000 (85%)]	Loss: 0.000763
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/116.pt
#
# Train Epoch: 117 [0/60000 (0%)]	Loss: 0.000765
# Train Epoch: 117 [25600/60000 (43%)]	Loss: 0.000596
# Train Epoch: 117 [51200/60000 (85%)]	Loss: 0.000666
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/117.pt
#
# Train Epoch: 118 [0/60000 (0%)]	Loss: 0.001076
# Train Epoch: 118 [25600/60000 (43%)]	Loss: 0.000652
# Train Epoch: 118 [51200/60000 (85%)]	Loss: 0.000957
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/118.pt
#
# Train Epoch: 119 [0/60000 (0%)]	Loss: 0.000802
# Train Epoch: 119 [25600/60000 (43%)]	Loss: 0.000575
# Train Epoch: 119 [51200/60000 (85%)]	Loss: 0.000769
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/119.pt
#
# Train Epoch: 120 [0/60000 (0%)]	Loss: 0.000405
# Train Epoch: 120 [25600/60000 (43%)]	Loss: 0.000685
# Train Epoch: 120 [51200/60000 (85%)]	Loss: 0.000678
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/120.pt
#
# Train Epoch: 121 [0/60000 (0%)]	Loss: 0.000587
# Train Epoch: 121 [25600/60000 (43%)]	Loss: 0.000666
# Train Epoch: 121 [51200/60000 (85%)]	Loss: 0.000459
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/121.pt
#
# Train Epoch: 122 [0/60000 (0%)]	Loss: 0.000793
# Train Epoch: 122 [25600/60000 (43%)]	Loss: 0.000661
# Train Epoch: 122 [51200/60000 (85%)]	Loss: 0.000952
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/122.pt
#
# Train Epoch: 123 [0/60000 (0%)]	Loss: 0.000590
# Train Epoch: 123 [25600/60000 (43%)]	Loss: 0.000880
# Train Epoch: 123 [51200/60000 (85%)]	Loss: 0.000741
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/123.pt
#
# Train Epoch: 124 [0/60000 (0%)]	Loss: 0.000519
# Train Epoch: 124 [25600/60000 (43%)]	Loss: 0.000603
# Train Epoch: 124 [51200/60000 (85%)]	Loss: 0.000679
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/124.pt
#
# Train Epoch: 125 [0/60000 (0%)]	Loss: 0.001029
# Train Epoch: 125 [25600/60000 (43%)]	Loss: 0.000548
# Train Epoch: 125 [51200/60000 (85%)]	Loss: 0.000572
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/125.pt
#
# Train Epoch: 126 [0/60000 (0%)]	Loss: 0.000312
# Train Epoch: 126 [25600/60000 (43%)]	Loss: 0.000890
# Train Epoch: 126 [51200/60000 (85%)]	Loss: 0.000549
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/126.pt
#
# Train Epoch: 127 [0/60000 (0%)]	Loss: 0.000566
# Train Epoch: 127 [25600/60000 (43%)]	Loss: 0.000602
# Train Epoch: 127 [51200/60000 (85%)]	Loss: 0.000827
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/127.pt
#
# Train Epoch: 128 [0/60000 (0%)]	Loss: 0.000579
# Train Epoch: 128 [25600/60000 (43%)]	Loss: 0.000657
# Train Epoch: 128 [51200/60000 (85%)]	Loss: 0.000563
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/128.pt
#
# Train Epoch: 129 [0/60000 (0%)]	Loss: 0.000631
# Train Epoch: 129 [25600/60000 (43%)]	Loss: 0.000821
# Train Epoch: 129 [51200/60000 (85%)]	Loss: 0.000649
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/129.pt
#
# Train Epoch: 130 [0/60000 (0%)]	Loss: 0.000345
# Train Epoch: 130 [25600/60000 (43%)]	Loss: 0.000858
# Train Epoch: 130 [51200/60000 (85%)]	Loss: 0.000537
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/130.pt
#
# Train Epoch: 131 [0/60000 (0%)]	Loss: 0.000930
# Train Epoch: 131 [25600/60000 (43%)]	Loss: 0.000793
# Train Epoch: 131 [51200/60000 (85%)]	Loss: 0.000669
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/131.pt
#
# Train Epoch: 132 [0/60000 (0%)]	Loss: 0.000486
# Train Epoch: 132 [25600/60000 (43%)]	Loss: 0.000795
# Train Epoch: 132 [51200/60000 (85%)]	Loss: 0.000485
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/132.pt
#
# Train Epoch: 133 [0/60000 (0%)]	Loss: 0.000490
# Train Epoch: 133 [25600/60000 (43%)]	Loss: 0.000556
# Train Epoch: 133 [51200/60000 (85%)]	Loss: 0.000906
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/133.pt
#
# Train Epoch: 134 [0/60000 (0%)]	Loss: 0.000791
# Train Epoch: 134 [25600/60000 (43%)]	Loss: 0.000527
# Train Epoch: 134 [51200/60000 (85%)]	Loss: 0.000358
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/134.pt
#
# Train Epoch: 135 [0/60000 (0%)]	Loss: 0.000891
# Train Epoch: 135 [25600/60000 (43%)]	Loss: 0.000516
# Train Epoch: 135 [51200/60000 (85%)]	Loss: 0.000714
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/135.pt
#
# Train Epoch: 136 [0/60000 (0%)]	Loss: 0.000510
# Train Epoch: 136 [25600/60000 (43%)]	Loss: 0.000412
# Train Epoch: 136 [51200/60000 (85%)]	Loss: 0.000605
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/136.pt
#
# Train Epoch: 137 [0/60000 (0%)]	Loss: 0.000778
# Train Epoch: 137 [25600/60000 (43%)]	Loss: 0.000405
# Train Epoch: 137 [51200/60000 (85%)]	Loss: 0.000455
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/137.pt
#
# Train Epoch: 138 [0/60000 (0%)]	Loss: 0.000765
# Train Epoch: 138 [25600/60000 (43%)]	Loss: 0.000543
# Train Epoch: 138 [51200/60000 (85%)]	Loss: 0.000632
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/138.pt
#
# Train Epoch: 139 [0/60000 (0%)]	Loss: 0.000386
# Train Epoch: 139 [25600/60000 (43%)]	Loss: 0.000562
# Train Epoch: 139 [51200/60000 (85%)]	Loss: 0.000719
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/139.pt
#
# Train Epoch: 140 [0/60000 (0%)]	Loss: 0.000516
# Train Epoch: 140 [25600/60000 (43%)]	Loss: 0.000272
# Train Epoch: 140 [51200/60000 (85%)]	Loss: 0.000586
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/140.pt
#
# Train Epoch: 141 [0/60000 (0%)]	Loss: 0.000807
# Train Epoch: 141 [25600/60000 (43%)]	Loss: 0.000539
# Train Epoch: 141 [51200/60000 (85%)]	Loss: 0.000790
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/141.pt
#
# Train Epoch: 142 [0/60000 (0%)]	Loss: 0.000655
# Train Epoch: 142 [25600/60000 (43%)]	Loss: 0.000554
# Train Epoch: 142 [51200/60000 (85%)]	Loss: 0.000531
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/142.pt
#
# Train Epoch: 143 [0/60000 (0%)]	Loss: 0.000754
# Train Epoch: 143 [25600/60000 (43%)]	Loss: 0.000261
# Train Epoch: 143 [51200/60000 (85%)]	Loss: 0.000502
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/143.pt
#
# Train Epoch: 144 [0/60000 (0%)]	Loss: 0.000437
# Train Epoch: 144 [25600/60000 (43%)]	Loss: 0.000512
# Train Epoch: 144 [51200/60000 (85%)]	Loss: 0.000432
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/144.pt
#
# Train Epoch: 145 [0/60000 (0%)]	Loss: 0.000394
# Train Epoch: 145 [25600/60000 (43%)]	Loss: 0.000631
# Train Epoch: 145 [51200/60000 (85%)]	Loss: 0.000844
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/145.pt
#
# Train Epoch: 146 [0/60000 (0%)]	Loss: 0.000475
# Train Epoch: 146 [25600/60000 (43%)]	Loss: 0.000521
# Train Epoch: 146 [51200/60000 (85%)]	Loss: 0.000615
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/146.pt
#
# Train Epoch: 147 [0/60000 (0%)]	Loss: 0.000392
# Train Epoch: 147 [25600/60000 (43%)]	Loss: 0.000935
# Train Epoch: 147 [51200/60000 (85%)]	Loss: 0.000307
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/147.pt
#
# Train Epoch: 148 [0/60000 (0%)]	Loss: 0.000388
# Train Epoch: 148 [25600/60000 (43%)]	Loss: 0.000461
# Train Epoch: 148 [51200/60000 (85%)]	Loss: 0.000747
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/148.pt
#
# Train Epoch: 149 [0/60000 (0%)]	Loss: 0.000578
# Train Epoch: 149 [25600/60000 (43%)]	Loss: 0.000808
# Train Epoch: 149 [51200/60000 (85%)]	Loss: 0.000679
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/149.pt
#
# Train Epoch: 150 [0/60000 (0%)]	Loss: 0.000698
# Train Epoch: 150 [25600/60000 (43%)]	Loss: 0.000469
# Train Epoch: 150 [51200/60000 (85%)]	Loss: 0.000430
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/150.pt
#
# Train Epoch: 151 [0/60000 (0%)]	Loss: 0.000619
# Train Epoch: 151 [25600/60000 (43%)]	Loss: 0.000618
# Train Epoch: 151 [51200/60000 (85%)]	Loss: 0.000483
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/151.pt
#
# Train Epoch: 152 [0/60000 (0%)]	Loss: 0.000516
# Train Epoch: 152 [25600/60000 (43%)]	Loss: 0.000745
# Train Epoch: 152 [51200/60000 (85%)]	Loss: 0.000317
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/152.pt
#
# Train Epoch: 153 [0/60000 (0%)]	Loss: 0.000451
# Train Epoch: 153 [25600/60000 (43%)]	Loss: 0.000331
# Train Epoch: 153 [51200/60000 (85%)]	Loss: 0.000583
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/153.pt
#
# Train Epoch: 154 [0/60000 (0%)]	Loss: 0.000249
# Train Epoch: 154 [25600/60000 (43%)]	Loss: 0.000399
# Train Epoch: 154 [51200/60000 (85%)]	Loss: 0.000359
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/154.pt
#
# Train Epoch: 155 [0/60000 (0%)]	Loss: 0.000614
# Train Epoch: 155 [25600/60000 (43%)]	Loss: 0.000497
# Train Epoch: 155 [51200/60000 (85%)]	Loss: 0.000523
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/155.pt
#
# Train Epoch: 156 [0/60000 (0%)]	Loss: 0.000627
# Train Epoch: 156 [25600/60000 (43%)]	Loss: 0.000350
# Train Epoch: 156 [51200/60000 (85%)]	Loss: 0.000710
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/156.pt
#
# Train Epoch: 157 [0/60000 (0%)]	Loss: 0.000317
# Train Epoch: 157 [25600/60000 (43%)]	Loss: 0.000467
# Train Epoch: 157 [51200/60000 (85%)]	Loss: 0.001066
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/157.pt
#
# Train Epoch: 158 [0/60000 (0%)]	Loss: 0.000575
# Train Epoch: 158 [25600/60000 (43%)]	Loss: 0.000672
# Train Epoch: 158 [51200/60000 (85%)]	Loss: 0.000642
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/158.pt
#
# Train Epoch: 159 [0/60000 (0%)]	Loss: 0.000349
# Train Epoch: 159 [25600/60000 (43%)]	Loss: 0.000560
# Train Epoch: 159 [51200/60000 (85%)]	Loss: 0.000490
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/159.pt
#
# Train Epoch: 160 [0/60000 (0%)]	Loss: 0.000547
# Train Epoch: 160 [25600/60000 (43%)]	Loss: 0.000532
# Train Epoch: 160 [51200/60000 (85%)]	Loss: 0.000561
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/160.pt
#
# Train Epoch: 161 [0/60000 (0%)]	Loss: 0.000309
# Train Epoch: 161 [25600/60000 (43%)]	Loss: 0.000587
# Train Epoch: 161 [51200/60000 (85%)]	Loss: 0.000433
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/161.pt
#
# Train Epoch: 162 [0/60000 (0%)]	Loss: 0.000470
# Train Epoch: 162 [25600/60000 (43%)]	Loss: 0.000422
# Train Epoch: 162 [51200/60000 (85%)]	Loss: 0.000288
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/162.pt
#
# Train Epoch: 163 [0/60000 (0%)]	Loss: 0.000497
# Train Epoch: 163 [25600/60000 (43%)]	Loss: 0.000521
# Train Epoch: 163 [51200/60000 (85%)]	Loss: 0.000666
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/163.pt
#
# Train Epoch: 164 [0/60000 (0%)]	Loss: 0.000318
# Train Epoch: 164 [25600/60000 (43%)]	Loss: 0.000394
# Train Epoch: 164 [51200/60000 (85%)]	Loss: 0.000362
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/164.pt
#
# Train Epoch: 165 [0/60000 (0%)]	Loss: 0.000422
# Train Epoch: 165 [25600/60000 (43%)]	Loss: 0.000473
# Train Epoch: 165 [51200/60000 (85%)]	Loss: 0.000345
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/165.pt
#
# Train Epoch: 166 [0/60000 (0%)]	Loss: 0.000514
# Train Epoch: 166 [25600/60000 (43%)]	Loss: 0.000449
# Train Epoch: 166 [51200/60000 (85%)]	Loss: 0.000442
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/166.pt
#
# Train Epoch: 167 [0/60000 (0%)]	Loss: 0.000553
# Train Epoch: 167 [25600/60000 (43%)]	Loss: 0.000371
# Train Epoch: 167 [51200/60000 (85%)]	Loss: 0.000527
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/167.pt
#
# Train Epoch: 168 [0/60000 (0%)]	Loss: 0.000356
# Train Epoch: 168 [25600/60000 (43%)]	Loss: 0.000408
# Train Epoch: 168 [51200/60000 (85%)]	Loss: 0.000409
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/168.pt
#
# Train Epoch: 169 [0/60000 (0%)]	Loss: 0.000231
# Train Epoch: 169 [25600/60000 (43%)]	Loss: 0.000837
# Train Epoch: 169 [51200/60000 (85%)]	Loss: 0.000626
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/169.pt
#
# Train Epoch: 170 [0/60000 (0%)]	Loss: 0.000367
# Train Epoch: 170 [25600/60000 (43%)]	Loss: 0.000383
# Train Epoch: 170 [51200/60000 (85%)]	Loss: 0.000400
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/170.pt
#
# Train Epoch: 171 [0/60000 (0%)]	Loss: 0.000438
# Train Epoch: 171 [25600/60000 (43%)]	Loss: 0.000458
# Train Epoch: 171 [51200/60000 (85%)]	Loss: 0.000454
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/171.pt
#
# Train Epoch: 172 [0/60000 (0%)]	Loss: 0.000744
# Train Epoch: 172 [25600/60000 (43%)]	Loss: 0.000337
# Train Epoch: 172 [51200/60000 (85%)]	Loss: 0.000658
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/172.pt
#
# Train Epoch: 173 [0/60000 (0%)]	Loss: 0.000363
# Train Epoch: 173 [25600/60000 (43%)]	Loss: 0.000547
# Train Epoch: 173 [51200/60000 (85%)]	Loss: 0.000503
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/173.pt
#
# Train Epoch: 174 [0/60000 (0%)]	Loss: 0.000554
# Train Epoch: 174 [25600/60000 (43%)]	Loss: 0.000247
# Train Epoch: 174 [51200/60000 (85%)]	Loss: 0.000462
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/174.pt
#
# Train Epoch: 175 [0/60000 (0%)]	Loss: 0.000611
# Train Epoch: 175 [25600/60000 (43%)]	Loss: 0.000485
# Train Epoch: 175 [51200/60000 (85%)]	Loss: 0.000669
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/175.pt
#
# Train Epoch: 176 [0/60000 (0%)]	Loss: 0.000218
# Train Epoch: 176 [25600/60000 (43%)]	Loss: 0.000457
# Train Epoch: 176 [51200/60000 (85%)]	Loss: 0.000421
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/176.pt
#
# Train Epoch: 177 [0/60000 (0%)]	Loss: 0.000437
# Train Epoch: 177 [25600/60000 (43%)]	Loss: 0.000388
# Train Epoch: 177 [51200/60000 (85%)]	Loss: 0.000434
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/177.pt
#
# Train Epoch: 178 [0/60000 (0%)]	Loss: 0.000486
# Train Epoch: 178 [25600/60000 (43%)]	Loss: 0.000259
# Train Epoch: 178 [51200/60000 (85%)]	Loss: 0.000432
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/178.pt
#
# Train Epoch: 179 [0/60000 (0%)]	Loss: 0.000279
# Train Epoch: 179 [25600/60000 (43%)]	Loss: 0.000458
# Train Epoch: 179 [51200/60000 (85%)]	Loss: 0.000384
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/179.pt
#
# Train Epoch: 180 [0/60000 (0%)]	Loss: 0.000483
# Train Epoch: 180 [25600/60000 (43%)]	Loss: 0.000351
# Train Epoch: 180 [51200/60000 (85%)]	Loss: 0.000348
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/180.pt
#
# Train Epoch: 181 [0/60000 (0%)]	Loss: 0.000374
# Train Epoch: 181 [25600/60000 (43%)]	Loss: 0.000559
# Train Epoch: 181 [51200/60000 (85%)]	Loss: 0.000288
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/181.pt
#
# Train Epoch: 182 [0/60000 (0%)]	Loss: 0.000301
# Train Epoch: 182 [25600/60000 (43%)]	Loss: 0.000309
# Train Epoch: 182 [51200/60000 (85%)]	Loss: 0.000511
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/182.pt
#
# Train Epoch: 183 [0/60000 (0%)]	Loss: 0.000304
# Train Epoch: 183 [25600/60000 (43%)]	Loss: 0.000311
# Train Epoch: 183 [51200/60000 (85%)]	Loss: 0.000359
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/183.pt
#
# Train Epoch: 184 [0/60000 (0%)]	Loss: 0.000348
# Train Epoch: 184 [25600/60000 (43%)]	Loss: 0.000289
# Train Epoch: 184 [51200/60000 (85%)]	Loss: 0.000604
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/184.pt
#
# Train Epoch: 185 [0/60000 (0%)]	Loss: 0.000383
# Train Epoch: 185 [25600/60000 (43%)]	Loss: 0.000185
# Train Epoch: 185 [51200/60000 (85%)]	Loss: 0.000345
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/185.pt
#
# Train Epoch: 186 [0/60000 (0%)]	Loss: 0.000389
# Train Epoch: 186 [25600/60000 (43%)]	Loss: 0.000328
# Train Epoch: 186 [51200/60000 (85%)]	Loss: 0.000532
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/186.pt
#
# Train Epoch: 187 [0/60000 (0%)]	Loss: 0.000586
# Train Epoch: 187 [25600/60000 (43%)]	Loss: 0.000385
# Train Epoch: 187 [51200/60000 (85%)]	Loss: 0.000546
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/187.pt
#
# Train Epoch: 188 [0/60000 (0%)]	Loss: 0.000355
# Train Epoch: 188 [25600/60000 (43%)]	Loss: 0.000398
# Train Epoch: 188 [51200/60000 (85%)]	Loss: 0.000490
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/188.pt
#
# Train Epoch: 189 [0/60000 (0%)]	Loss: 0.000307
# Train Epoch: 189 [25600/60000 (43%)]	Loss: 0.000318
# Train Epoch: 189 [51200/60000 (85%)]	Loss: 0.000337
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/189.pt
#
# Train Epoch: 190 [0/60000 (0%)]	Loss: 0.000362
# Train Epoch: 190 [25600/60000 (43%)]	Loss: 0.000285
# Train Epoch: 190 [51200/60000 (85%)]	Loss: 0.000463
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/190.pt
#
# Train Epoch: 191 [0/60000 (0%)]	Loss: 0.000384
# Train Epoch: 191 [25600/60000 (43%)]	Loss: 0.000603
# Train Epoch: 191 [51200/60000 (85%)]	Loss: 0.000276
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/191.pt
#
# Train Epoch: 192 [0/60000 (0%)]	Loss: 0.000252
# Train Epoch: 192 [25600/60000 (43%)]	Loss: 0.000521
# Train Epoch: 192 [51200/60000 (85%)]	Loss: 0.000287
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/192.pt
#
# Train Epoch: 193 [0/60000 (0%)]	Loss: 0.000510
# Train Epoch: 193 [25600/60000 (43%)]	Loss: 0.000458
# Train Epoch: 193 [51200/60000 (85%)]	Loss: 0.000415
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/193.pt
#
# Train Epoch: 194 [0/60000 (0%)]	Loss: 0.000334
# Train Epoch: 194 [25600/60000 (43%)]	Loss: 0.000397
# Train Epoch: 194 [51200/60000 (85%)]	Loss: 0.000334
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/194.pt
#
# Train Epoch: 195 [0/60000 (0%)]	Loss: 0.000433
# Train Epoch: 195 [25600/60000 (43%)]	Loss: 0.000431
# Train Epoch: 195 [51200/60000 (85%)]	Loss: 0.000533
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/195.pt
#
# Train Epoch: 196 [0/60000 (0%)]	Loss: 0.000423
# Train Epoch: 196 [25600/60000 (43%)]	Loss: 0.000502
# Train Epoch: 196 [51200/60000 (85%)]	Loss: 0.000336
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/196.pt
#
# Train Epoch: 197 [0/60000 (0%)]	Loss: 0.000415
# Train Epoch: 197 [25600/60000 (43%)]	Loss: 0.000453
# Train Epoch: 197 [51200/60000 (85%)]	Loss: 0.000332
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/197.pt
#
# Train Epoch: 198 [0/60000 (0%)]	Loss: 0.000320
# Train Epoch: 198 [25600/60000 (43%)]	Loss: 0.000585
# Train Epoch: 198 [51200/60000 (85%)]	Loss: 0.000381
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/198.pt
#
# Train Epoch: 199 [0/60000 (0%)]	Loss: 0.000224
# Train Epoch: 199 [25600/60000 (43%)]	Loss: 0.000498
# Train Epoch: 199 [51200/60000 (85%)]	Loss: 0.000341
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/199.pt
#
# Train Epoch: 200 [0/60000 (0%)]	Loss: 0.000457
# Train Epoch: 200 [25600/60000 (43%)]	Loss: 0.000499
# Train Epoch: 200 [51200/60000 (85%)]	Loss: 0.000270
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/200.pt
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/200.pt

# %% [markdown]
# # Part 2: Reimplementing the Cross Entropy loss function.

# %%
class MNISTNetNewLoss(MNISTNet):
  
    def loss(self, prediction, label, reduction='elementwise_mean'): 
        # Reimplement the Cross Entropy loss function using mathematical primitives.
        # This means you are not allowed to use any function in the "Loss functions" 
        # section of https://pytorch.org/docs/stable/nn.html#id50 nor the 
        # functional versions. You can use them to verify that your output looks correct.
        # You should implement reduction for none (i.e. return a vector, sum, and elementwise_mean).
        # Note: Due to floating point errors, the values won't be exactly equal.
        # Second note: You can assume inputs will be 2D (batch X features).
        loss_val_old = super(MNISTNetNewLoss, self).loss(prediction, label, reduction)
        batch_size = prediction.shape[0]
        prediction = F.log_softmax(prediction, dim=1)
        prediction = prediction[range(batch_size), label]
        loss_val_new = -torch.sum(prediction) / batch_size
        
#         raise NotImplementedError('Define the loss here')

        
        assert(abs(loss_val_new - loss_val_old).item() < 0.01)
        return loss_val_new

# %%
# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=TEST_BATCH_SIZE, **kwargs)


model = MNISTNetNewLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
start_epoch = model.load_last_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints')
try:
    for epoch in range(start_epoch, EPOCHS + 1):
        train(model, device, train_loader, optimizer, epoch, LOG_INTERVAL)
        test(model, device, test_loader)
        model.save_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/%03d.pt' % epoch)
except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/%03d.pt' % epoch)
# Out:
# Using device cuda
# num cpus: 2
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.321626
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.629896
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.343953
#
# Test set: Average loss: 0.0003, Accuracy: 9035/10000 (90%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/000.pt
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.382503
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.273441
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.226505
#
# Test set: Average loss: 0.0003, Accuracy: 9245/10000 (92%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/001.pt
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.237738
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.215299
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.184501
#
# Test set: Average loss: 0.0002, Accuracy: 9367/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/002.pt
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.234877
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.251013
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.156055
#
# Test set: Average loss: 0.0002, Accuracy: 9449/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/003.pt
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.227616
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.188198
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.177204
#
# Test set: Average loss: 0.0002, Accuracy: 9499/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/004.pt
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.191296
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.130595
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.157843
#
# Test set: Average loss: 0.0002, Accuracy: 9546/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/005.pt
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.139316
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.120627
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.128907
#
# Test set: Average loss: 0.0001, Accuracy: 9591/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/006.pt
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.140010
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.121134
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.096819
#
# Test set: Average loss: 0.0001, Accuracy: 9628/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/007.pt
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.127019
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.102405
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.151826
#
# Test set: Average loss: 0.0001, Accuracy: 9652/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/008.pt
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.126826
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.132106
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.088998
#
# Test set: Average loss: 0.0001, Accuracy: 9671/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/009.pt
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.080407
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.099713
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.097544
#
# Test set: Average loss: 0.0001, Accuracy: 9697/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/010.pt
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.064248
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 0.073675
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.078721
#
# Test set: Average loss: 0.0001, Accuracy: 9693/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/011.pt
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.088433
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 0.074742
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.103594
#
# Test set: Average loss: 0.0001, Accuracy: 9713/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/012.pt
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.068155
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 0.120605
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.085814
#
# Test set: Average loss: 0.0001, Accuracy: 9724/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/013.pt
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.051239
# Train Epoch: 14 [25600/60000 (43%)]	Loss: 0.061378
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 0.067736
#
# Test set: Average loss: 0.0001, Accuracy: 9749/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/014.pt
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.112087
# Train Epoch: 15 [25600/60000 (43%)]	Loss: 0.055292
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 0.038306
#
# Test set: Average loss: 0.0001, Accuracy: 9748/10000 (97%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/015.pt
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.037679
# Train Epoch: 16 [25600/60000 (43%)]	Loss: 0.062335
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 0.064028
#
# Test set: Average loss: 0.0001, Accuracy: 9755/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/016.pt
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.043707
# Train Epoch: 17 [25600/60000 (43%)]	Loss: 0.033119
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 0.091757
#
# Test set: Average loss: 0.0001, Accuracy: 9762/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/017.pt
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.052393
# Train Epoch: 18 [25600/60000 (43%)]	Loss: 0.039472
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 0.041947
#
# Test set: Average loss: 0.0001, Accuracy: 9772/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/018.pt
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.037715
# Train Epoch: 19 [25600/60000 (43%)]	Loss: 0.061209
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 0.045493
#
# Test set: Average loss: 0.0001, Accuracy: 9773/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/019.pt
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.030267
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 0.038940
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 0.034767
#
# Test set: Average loss: 0.0001, Accuracy: 9774/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/020.pt
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.065458
# Train Epoch: 21 [25600/60000 (43%)]	Loss: 0.076273
# Train Epoch: 21 [51200/60000 (85%)]	Loss: 0.036919
#
# Test set: Average loss: 0.0001, Accuracy: 9778/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/021.pt
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.043511
# Train Epoch: 22 [25600/60000 (43%)]	Loss: 0.053066
# Train Epoch: 22 [51200/60000 (85%)]	Loss: 0.036238
#
# Test set: Average loss: 0.0001, Accuracy: 9773/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/022.pt
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.031714
# Train Epoch: 23 [25600/60000 (43%)]	Loss: 0.026562
# Train Epoch: 23 [51200/60000 (85%)]	Loss: 0.039746
#
# Test set: Average loss: 0.0001, Accuracy: 9784/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/023.pt
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.045479
# Train Epoch: 24 [25600/60000 (43%)]	Loss: 0.028887
# Train Epoch: 24 [51200/60000 (85%)]	Loss: 0.017392
#
# Test set: Average loss: 0.0001, Accuracy: 9787/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/024.pt
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.085828
# Train Epoch: 25 [25600/60000 (43%)]	Loss: 0.023391
# Train Epoch: 25 [51200/60000 (85%)]	Loss: 0.032322
#
# Test set: Average loss: 0.0001, Accuracy: 9789/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/025.pt
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.020522
# Train Epoch: 26 [25600/60000 (43%)]	Loss: 0.019605
# Train Epoch: 26 [51200/60000 (85%)]	Loss: 0.025598
#
# Test set: Average loss: 0.0001, Accuracy: 9789/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/026.pt
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.033933
# Train Epoch: 27 [25600/60000 (43%)]	Loss: 0.017523
# Train Epoch: 27 [51200/60000 (85%)]	Loss: 0.025988
#
# Test set: Average loss: 0.0001, Accuracy: 9784/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/027.pt
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.039964
# Train Epoch: 28 [25600/60000 (43%)]	Loss: 0.030132
# Train Epoch: 28 [51200/60000 (85%)]	Loss: 0.025971
#
# Test set: Average loss: 0.0001, Accuracy: 9801/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/028.pt
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.013883
# Train Epoch: 29 [25600/60000 (43%)]	Loss: 0.017835
# Train Epoch: 29 [51200/60000 (85%)]	Loss: 0.050683
#
# Test set: Average loss: 0.0001, Accuracy: 9785/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/029.pt
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.019307
# Train Epoch: 30 [25600/60000 (43%)]	Loss: 0.011929
# Train Epoch: 30 [51200/60000 (85%)]	Loss: 0.021898
#
# Test set: Average loss: 0.0001, Accuracy: 9798/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/030.pt
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.024828
# Train Epoch: 31 [25600/60000 (43%)]	Loss: 0.020368
# Train Epoch: 31 [51200/60000 (85%)]	Loss: 0.026066
#
# Test set: Average loss: 0.0001, Accuracy: 9790/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/031.pt
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.020326
# Train Epoch: 32 [25600/60000 (43%)]	Loss: 0.025014
# Train Epoch: 32 [51200/60000 (85%)]	Loss: 0.023171
#
# Test set: Average loss: 0.0001, Accuracy: 9799/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/032.pt
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.026906
# Train Epoch: 33 [25600/60000 (43%)]	Loss: 0.008780
# Train Epoch: 33 [51200/60000 (85%)]	Loss: 0.013643
#
# Test set: Average loss: 0.0001, Accuracy: 9796/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/033.pt
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.010748
# Train Epoch: 34 [25600/60000 (43%)]	Loss: 0.016310
# Train Epoch: 34 [51200/60000 (85%)]	Loss: 0.013669
#
# Test set: Average loss: 0.0001, Accuracy: 9795/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/034.pt
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.011565
# Train Epoch: 35 [25600/60000 (43%)]	Loss: 0.017846
# Train Epoch: 35 [51200/60000 (85%)]	Loss: 0.073456
#
# Test set: Average loss: 0.0001, Accuracy: 9803/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/035.pt
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.009862
# Train Epoch: 36 [25600/60000 (43%)]	Loss: 0.013383
# Train Epoch: 36 [51200/60000 (85%)]	Loss: 0.020290
#
# Test set: Average loss: 0.0001, Accuracy: 9797/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/036.pt
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.008885
# Train Epoch: 37 [25600/60000 (43%)]	Loss: 0.018969
# Train Epoch: 37 [51200/60000 (85%)]	Loss: 0.008244
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/037.pt
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.009237
# Train Epoch: 38 [25600/60000 (43%)]	Loss: 0.010938
# Train Epoch: 38 [51200/60000 (85%)]	Loss: 0.031632
#
# Test set: Average loss: 0.0001, Accuracy: 9807/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/038.pt
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.011188
# Train Epoch: 39 [25600/60000 (43%)]	Loss: 0.016253
# Train Epoch: 39 [51200/60000 (85%)]	Loss: 0.023409
#
# Test set: Average loss: 0.0001, Accuracy: 9806/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/039.pt
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.019290
# Train Epoch: 40 [25600/60000 (43%)]	Loss: 0.010707
# Train Epoch: 40 [51200/60000 (85%)]	Loss: 0.009992
#
# Test set: Average loss: 0.0001, Accuracy: 9805/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/040.pt
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.013361
# Train Epoch: 41 [25600/60000 (43%)]	Loss: 0.019599
# Train Epoch: 41 [51200/60000 (85%)]	Loss: 0.007135
#
# Test set: Average loss: 0.0001, Accuracy: 9810/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/041.pt
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.010214
# Train Epoch: 42 [25600/60000 (43%)]	Loss: 0.012830
# Train Epoch: 42 [51200/60000 (85%)]	Loss: 0.008146
#
# Test set: Average loss: 0.0001, Accuracy: 9800/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/042.pt
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.010929
# Train Epoch: 43 [25600/60000 (43%)]	Loss: 0.005364
# Train Epoch: 43 [51200/60000 (85%)]	Loss: 0.011303
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/043.pt
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.004564
# Train Epoch: 44 [25600/60000 (43%)]	Loss: 0.006697
# Train Epoch: 44 [51200/60000 (85%)]	Loss: 0.005692
#
# Test set: Average loss: 0.0001, Accuracy: 9804/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/044.pt
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.011546
# Train Epoch: 45 [25600/60000 (43%)]	Loss: 0.008127
# Train Epoch: 45 [51200/60000 (85%)]	Loss: 0.008873
#
# Test set: Average loss: 0.0001, Accuracy: 9804/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/045.pt
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.009044
# Train Epoch: 46 [25600/60000 (43%)]	Loss: 0.006991
# Train Epoch: 46 [51200/60000 (85%)]	Loss: 0.014354
#
# Test set: Average loss: 0.0001, Accuracy: 9805/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/046.pt
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.005321
# Train Epoch: 47 [25600/60000 (43%)]	Loss: 0.007612
# Train Epoch: 47 [51200/60000 (85%)]	Loss: 0.015563
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/047.pt
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.007961
# Train Epoch: 48 [25600/60000 (43%)]	Loss: 0.011445
# Train Epoch: 48 [51200/60000 (85%)]	Loss: 0.010043
#
# Test set: Average loss: 0.0001, Accuracy: 9806/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/048.pt
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.005631
# Train Epoch: 49 [25600/60000 (43%)]	Loss: 0.008816
# Train Epoch: 49 [51200/60000 (85%)]	Loss: 0.010385
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/049.pt
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.017011
# Train Epoch: 50 [25600/60000 (43%)]	Loss: 0.008990
# Train Epoch: 50 [51200/60000 (85%)]	Loss: 0.008701
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/050.pt
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 0.004771
# Train Epoch: 51 [25600/60000 (43%)]	Loss: 0.008571
# Train Epoch: 51 [51200/60000 (85%)]	Loss: 0.006600
#
# Test set: Average loss: 0.0001, Accuracy: 9809/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/051.pt
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.006323
# Train Epoch: 52 [25600/60000 (43%)]	Loss: 0.005665
# Train Epoch: 52 [51200/60000 (85%)]	Loss: 0.004448
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/052.pt
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.006918
# Train Epoch: 53 [25600/60000 (43%)]	Loss: 0.006009
# Train Epoch: 53 [51200/60000 (85%)]	Loss: 0.007322
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/053.pt
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.004406
# Train Epoch: 54 [25600/60000 (43%)]	Loss: 0.004876
# Train Epoch: 54 [51200/60000 (85%)]	Loss: 0.004457
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/054.pt
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.006191
# Train Epoch: 55 [25600/60000 (43%)]	Loss: 0.005841
# Train Epoch: 55 [51200/60000 (85%)]	Loss: 0.005061
#
# Test set: Average loss: 0.0001, Accuracy: 9804/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/055.pt
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.005555
# Train Epoch: 56 [25600/60000 (43%)]	Loss: 0.004670
# Train Epoch: 56 [51200/60000 (85%)]	Loss: 0.005217
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/056.pt
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.005910
# Train Epoch: 57 [25600/60000 (43%)]	Loss: 0.004469
# Train Epoch: 57 [51200/60000 (85%)]	Loss: 0.005497
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/057.pt
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.003706
# Train Epoch: 58 [25600/60000 (43%)]	Loss: 0.004498
# Train Epoch: 58 [51200/60000 (85%)]	Loss: 0.004772
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/058.pt
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 0.002477
# Train Epoch: 59 [25600/60000 (43%)]	Loss: 0.010086
# Train Epoch: 59 [51200/60000 (85%)]	Loss: 0.006803
#
# Test set: Average loss: 0.0001, Accuracy: 9807/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/059.pt
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.003062
# Train Epoch: 60 [25600/60000 (43%)]	Loss: 0.004213
# Train Epoch: 60 [51200/60000 (85%)]	Loss: 0.004417
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/060.pt
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.003962
# Train Epoch: 61 [25600/60000 (43%)]	Loss: 0.005195
# Train Epoch: 61 [51200/60000 (85%)]	Loss: 0.005026
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/061.pt
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.010740
# Train Epoch: 62 [25600/60000 (43%)]	Loss: 0.002353
# Train Epoch: 62 [51200/60000 (85%)]	Loss: 0.006831
#
# Test set: Average loss: 0.0001, Accuracy: 9807/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/062.pt
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.003160
# Train Epoch: 63 [25600/60000 (43%)]	Loss: 0.004403
# Train Epoch: 63 [51200/60000 (85%)]	Loss: 0.005954
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/063.pt
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.005361
# Train Epoch: 64 [25600/60000 (43%)]	Loss: 0.002167
# Train Epoch: 64 [51200/60000 (85%)]	Loss: 0.004158
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/064.pt
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.005466
# Train Epoch: 65 [25600/60000 (43%)]	Loss: 0.005164
# Train Epoch: 65 [51200/60000 (85%)]	Loss: 0.005313
#
# Test set: Average loss: 0.0001, Accuracy: 9809/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/065.pt
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.002572
# Train Epoch: 66 [25600/60000 (43%)]	Loss: 0.004148
# Train Epoch: 66 [51200/60000 (85%)]	Loss: 0.004214
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/066.pt
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.003481
# Train Epoch: 67 [25600/60000 (43%)]	Loss: 0.003457
# Train Epoch: 67 [51200/60000 (85%)]	Loss: 0.004673
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/067.pt
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.004259
# Train Epoch: 68 [25600/60000 (43%)]	Loss: 0.001994
# Train Epoch: 68 [51200/60000 (85%)]	Loss: 0.004631
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/068.pt
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.002172
# Train Epoch: 69 [25600/60000 (43%)]	Loss: 0.004022
# Train Epoch: 69 [51200/60000 (85%)]	Loss: 0.003393
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/069.pt
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.003987
# Train Epoch: 70 [25600/60000 (43%)]	Loss: 0.002913
# Train Epoch: 70 [51200/60000 (85%)]	Loss: 0.002454
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/070.pt
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.003346
# Train Epoch: 71 [25600/60000 (43%)]	Loss: 0.004627
# Train Epoch: 71 [51200/60000 (85%)]	Loss: 0.002405
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/071.pt
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.002313
# Train Epoch: 72 [25600/60000 (43%)]	Loss: 0.002012
# Train Epoch: 72 [51200/60000 (85%)]	Loss: 0.004050
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/072.pt
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.002243
# Train Epoch: 73 [25600/60000 (43%)]	Loss: 0.002565
# Train Epoch: 73 [51200/60000 (85%)]	Loss: 0.002996
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/073.pt
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.002004
# Train Epoch: 74 [25600/60000 (43%)]	Loss: 0.002118
# Train Epoch: 74 [51200/60000 (85%)]	Loss: 0.005566
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/074.pt
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.003489
# Train Epoch: 75 [25600/60000 (43%)]	Loss: 0.001778
# Train Epoch: 75 [51200/60000 (85%)]	Loss: 0.002702
#
# Test set: Average loss: 0.0001, Accuracy: 9810/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/075.pt
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.003209
# Train Epoch: 76 [25600/60000 (43%)]	Loss: 0.002365
# Train Epoch: 76 [51200/60000 (85%)]	Loss: 0.003349
#
# Test set: Average loss: 0.0001, Accuracy: 9810/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/076.pt
#
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.004074
# Train Epoch: 77 [25600/60000 (43%)]	Loss: 0.002564
# Train Epoch: 77 [51200/60000 (85%)]	Loss: 0.004740
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/077.pt
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.002727
# Train Epoch: 78 [25600/60000 (43%)]	Loss: 0.002547
# Train Epoch: 78 [51200/60000 (85%)]	Loss: 0.003248
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/078.pt
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.001947
# Train Epoch: 79 [25600/60000 (43%)]	Loss: 0.002005
# Train Epoch: 79 [51200/60000 (85%)]	Loss: 0.001788
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/079.pt
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.002509
# Train Epoch: 80 [25600/60000 (43%)]	Loss: 0.002422
# Train Epoch: 80 [51200/60000 (85%)]	Loss: 0.003448
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/080.pt
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 0.002648
# Train Epoch: 81 [25600/60000 (43%)]	Loss: 0.003917
# Train Epoch: 81 [51200/60000 (85%)]	Loss: 0.001776
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/081.pt
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.001877
# Train Epoch: 82 [25600/60000 (43%)]	Loss: 0.007242
# Train Epoch: 82 [51200/60000 (85%)]	Loss: 0.002068
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/082.pt
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.002816
# Train Epoch: 83 [25600/60000 (43%)]	Loss: 0.002672
# Train Epoch: 83 [51200/60000 (85%)]	Loss: 0.002675
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/083.pt
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.001833
# Train Epoch: 84 [25600/60000 (43%)]	Loss: 0.002310
# Train Epoch: 84 [51200/60000 (85%)]	Loss: 0.002581
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/084.pt
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 0.002298
# Train Epoch: 85 [25600/60000 (43%)]	Loss: 0.002849
# Train Epoch: 85 [51200/60000 (85%)]	Loss: 0.003017
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/085.pt
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.001885
# Train Epoch: 86 [25600/60000 (43%)]	Loss: 0.003460
# Train Epoch: 86 [51200/60000 (85%)]	Loss: 0.001993
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/086.pt
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.002600
# Train Epoch: 87 [25600/60000 (43%)]	Loss: 0.002891
# Train Epoch: 87 [51200/60000 (85%)]	Loss: 0.002175
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/087.pt
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.002016
# Train Epoch: 88 [25600/60000 (43%)]	Loss: 0.003380
# Train Epoch: 88 [51200/60000 (85%)]	Loss: 0.002298
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/088.pt
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.001503
# Train Epoch: 89 [25600/60000 (43%)]	Loss: 0.002945
# Train Epoch: 89 [51200/60000 (85%)]	Loss: 0.001925
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/089.pt
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.002731
# Train Epoch: 90 [25600/60000 (43%)]	Loss: 0.003080
# Train Epoch: 90 [51200/60000 (85%)]	Loss: 0.001581
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/090.pt
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.002681
# Train Epoch: 91 [25600/60000 (43%)]	Loss: 0.002843
# Train Epoch: 91 [51200/60000 (85%)]	Loss: 0.001524
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/091.pt
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.002895
# Train Epoch: 92 [25600/60000 (43%)]	Loss: 0.001678
# Train Epoch: 92 [51200/60000 (85%)]	Loss: 0.000692
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/092.pt
#
# Train Epoch: 93 [0/60000 (0%)]	Loss: 0.002334
# Train Epoch: 93 [25600/60000 (43%)]	Loss: 0.002112
# Train Epoch: 93 [51200/60000 (85%)]	Loss: 0.002443
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/093.pt
#
# Train Epoch: 94 [0/60000 (0%)]	Loss: 0.002482
# Train Epoch: 94 [25600/60000 (43%)]	Loss: 0.001891
# Train Epoch: 94 [51200/60000 (85%)]	Loss: 0.002474
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/094.pt
#
# Train Epoch: 95 [0/60000 (0%)]	Loss: 0.004287
# Train Epoch: 95 [25600/60000 (43%)]	Loss: 0.001780
# Train Epoch: 95 [51200/60000 (85%)]	Loss: 0.000963
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/095.pt
#
# Train Epoch: 96 [0/60000 (0%)]	Loss: 0.003049
# Train Epoch: 96 [25600/60000 (43%)]	Loss: 0.002539
# Train Epoch: 96 [51200/60000 (85%)]	Loss: 0.002285
#
# Test set: Average loss: 0.0001, Accuracy: 9813/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/096.pt
#
# Train Epoch: 97 [0/60000 (0%)]	Loss: 0.001215
# Train Epoch: 97 [25600/60000 (43%)]	Loss: 0.002156
# Train Epoch: 97 [51200/60000 (85%)]	Loss: 0.001402
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/097.pt
#
# Train Epoch: 98 [0/60000 (0%)]	Loss: 0.002067
# Train Epoch: 98 [25600/60000 (43%)]	Loss: 0.002191
# Train Epoch: 98 [51200/60000 (85%)]	Loss: 0.003781
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/098.pt
#
# Train Epoch: 99 [0/60000 (0%)]	Loss: 0.001481
# Train Epoch: 99 [25600/60000 (43%)]	Loss: 0.001866
# Train Epoch: 99 [51200/60000 (85%)]	Loss: 0.002306
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/099.pt
#
# Train Epoch: 100 [0/60000 (0%)]	Loss: 0.001134
# Train Epoch: 100 [25600/60000 (43%)]	Loss: 0.001529
# Train Epoch: 100 [51200/60000 (85%)]	Loss: 0.001572
#
# Test set: Average loss: 0.0001, Accuracy: 9811/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/100.pt
#
# Train Epoch: 101 [0/60000 (0%)]	Loss: 0.001982
# Train Epoch: 101 [25600/60000 (43%)]	Loss: 0.001508
# Train Epoch: 101 [51200/60000 (85%)]	Loss: 0.001633
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/101.pt
#
# Train Epoch: 102 [0/60000 (0%)]	Loss: 0.001000
# Train Epoch: 102 [25600/60000 (43%)]	Loss: 0.004487
# Train Epoch: 102 [51200/60000 (85%)]	Loss: 0.002265
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/102.pt
#
# Train Epoch: 103 [0/60000 (0%)]	Loss: 0.001346
# Train Epoch: 103 [25600/60000 (43%)]	Loss: 0.001669
# Train Epoch: 103 [51200/60000 (85%)]	Loss: 0.001420
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/103.pt
#
# Train Epoch: 104 [0/60000 (0%)]	Loss: 0.001404
# Train Epoch: 104 [25600/60000 (43%)]	Loss: 0.001344
# Train Epoch: 104 [51200/60000 (85%)]	Loss: 0.001650
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/104.pt
#
# Train Epoch: 105 [0/60000 (0%)]	Loss: 0.001517
# Train Epoch: 105 [25600/60000 (43%)]	Loss: 0.001084
# Train Epoch: 105 [51200/60000 (85%)]	Loss: 0.001856
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/105.pt
#
# Train Epoch: 106 [0/60000 (0%)]	Loss: 0.002227
# Train Epoch: 106 [25600/60000 (43%)]	Loss: 0.001229
# Train Epoch: 106 [51200/60000 (85%)]	Loss: 0.002139
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/106.pt
#
# Train Epoch: 107 [0/60000 (0%)]	Loss: 0.001530
# Train Epoch: 107 [25600/60000 (43%)]	Loss: 0.001684
# Train Epoch: 107 [51200/60000 (85%)]	Loss: 0.001771
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/107.pt
#
# Train Epoch: 108 [0/60000 (0%)]	Loss: 0.001646
# Train Epoch: 108 [25600/60000 (43%)]	Loss: 0.001069
# Train Epoch: 108 [51200/60000 (85%)]	Loss: 0.001634
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/108.pt
#
# Train Epoch: 109 [0/60000 (0%)]	Loss: 0.001686
# Train Epoch: 109 [25600/60000 (43%)]	Loss: 0.000992
# Train Epoch: 109 [51200/60000 (85%)]	Loss: 0.001242
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/109.pt
#
# Train Epoch: 110 [0/60000 (0%)]	Loss: 0.001025
# Train Epoch: 110 [25600/60000 (43%)]	Loss: 0.001981
# Train Epoch: 110 [51200/60000 (85%)]	Loss: 0.001374
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/110.pt
#
# Train Epoch: 111 [0/60000 (0%)]	Loss: 0.001326
# Train Epoch: 111 [25600/60000 (43%)]	Loss: 0.001157
# Train Epoch: 111 [51200/60000 (85%)]	Loss: 0.001767
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/111.pt
#
# Train Epoch: 112 [0/60000 (0%)]	Loss: 0.001722
# Train Epoch: 112 [25600/60000 (43%)]	Loss: 0.001206
# Train Epoch: 112 [51200/60000 (85%)]	Loss: 0.001708
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/112.pt
#
# Train Epoch: 113 [0/60000 (0%)]	Loss: 0.001351
# Train Epoch: 113 [25600/60000 (43%)]	Loss: 0.001466
# Train Epoch: 113 [51200/60000 (85%)]	Loss: 0.001700
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/113.pt
#
# Train Epoch: 114 [0/60000 (0%)]	Loss: 0.001211
# Train Epoch: 114 [25600/60000 (43%)]	Loss: 0.001579
# Train Epoch: 114 [51200/60000 (85%)]	Loss: 0.001331
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/114.pt
#
# Train Epoch: 115 [0/60000 (0%)]	Loss: 0.000700
# Train Epoch: 115 [25600/60000 (43%)]	Loss: 0.001897
# Train Epoch: 115 [51200/60000 (85%)]	Loss: 0.001026
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/115.pt
#
# Train Epoch: 116 [0/60000 (0%)]	Loss: 0.000930
# Train Epoch: 116 [25600/60000 (43%)]	Loss: 0.001454
# Train Epoch: 116 [51200/60000 (85%)]	Loss: 0.001685
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/116.pt
#
# Train Epoch: 117 [0/60000 (0%)]	Loss: 0.001640
# Train Epoch: 117 [25600/60000 (43%)]	Loss: 0.002350
# Train Epoch: 117 [51200/60000 (85%)]	Loss: 0.000880
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/117.pt
#
# Train Epoch: 118 [0/60000 (0%)]	Loss: 0.001622
# Train Epoch: 118 [25600/60000 (43%)]	Loss: 0.002398
# Train Epoch: 118 [51200/60000 (85%)]	Loss: 0.000897
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/118.pt
#
# Train Epoch: 119 [0/60000 (0%)]	Loss: 0.001420
# Train Epoch: 119 [25600/60000 (43%)]	Loss: 0.001076
# Train Epoch: 119 [51200/60000 (85%)]	Loss: 0.001679
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/119.pt
#
# Train Epoch: 120 [0/60000 (0%)]	Loss: 0.001359
# Train Epoch: 120 [25600/60000 (43%)]	Loss: 0.001039
# Train Epoch: 120 [51200/60000 (85%)]	Loss: 0.001650
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/120.pt
#
# Train Epoch: 121 [0/60000 (0%)]	Loss: 0.000864
# Train Epoch: 121 [25600/60000 (43%)]	Loss: 0.001049
# Train Epoch: 121 [51200/60000 (85%)]	Loss: 0.000909
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/121.pt
#
# Train Epoch: 122 [0/60000 (0%)]	Loss: 0.001214
# Train Epoch: 122 [25600/60000 (43%)]	Loss: 0.000851
# Train Epoch: 122 [51200/60000 (85%)]	Loss: 0.001071
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/122.pt
#
# Train Epoch: 123 [0/60000 (0%)]	Loss: 0.001817
# Train Epoch: 123 [25600/60000 (43%)]	Loss: 0.000800
# Train Epoch: 123 [51200/60000 (85%)]	Loss: 0.001207
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/123.pt
#
# Train Epoch: 124 [0/60000 (0%)]	Loss: 0.000970
# Train Epoch: 124 [25600/60000 (43%)]	Loss: 0.001194
# Train Epoch: 124 [51200/60000 (85%)]	Loss: 0.001551
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/124.pt
#
# Train Epoch: 125 [0/60000 (0%)]	Loss: 0.000937
# Train Epoch: 125 [25600/60000 (43%)]	Loss: 0.001333
# Train Epoch: 125 [51200/60000 (85%)]	Loss: 0.001362
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/125.pt
#
# Train Epoch: 126 [0/60000 (0%)]	Loss: 0.001967
# Train Epoch: 126 [25600/60000 (43%)]	Loss: 0.000852
# Train Epoch: 126 [51200/60000 (85%)]	Loss: 0.001082
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/126.pt
#
# Train Epoch: 127 [0/60000 (0%)]	Loss: 0.001816
# Train Epoch: 127 [25600/60000 (43%)]	Loss: 0.000610
# Train Epoch: 127 [51200/60000 (85%)]	Loss: 0.001001
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/127.pt
#
# Train Epoch: 128 [0/60000 (0%)]	Loss: 0.000577
# Train Epoch: 128 [25600/60000 (43%)]	Loss: 0.000984
# Train Epoch: 128 [51200/60000 (85%)]	Loss: 0.001313
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/128.pt
#
# Train Epoch: 129 [0/60000 (0%)]	Loss: 0.000818
# Train Epoch: 129 [25600/60000 (43%)]	Loss: 0.001318
# Train Epoch: 129 [51200/60000 (85%)]	Loss: 0.001058
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/129.pt
#
# Train Epoch: 130 [0/60000 (0%)]	Loss: 0.000795
# Train Epoch: 130 [25600/60000 (43%)]	Loss: 0.001150
# Train Epoch: 130 [51200/60000 (85%)]	Loss: 0.000800
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/130.pt
#
# Train Epoch: 131 [0/60000 (0%)]	Loss: 0.001178
# Train Epoch: 131 [25600/60000 (43%)]	Loss: 0.001107
# Train Epoch: 131 [51200/60000 (85%)]	Loss: 0.001136
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/131.pt
#
# Train Epoch: 132 [0/60000 (0%)]	Loss: 0.001288
# Train Epoch: 132 [25600/60000 (43%)]	Loss: 0.000631
# Train Epoch: 132 [51200/60000 (85%)]	Loss: 0.001212
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/132.pt
#
# Train Epoch: 133 [0/60000 (0%)]	Loss: 0.000913
# Train Epoch: 133 [25600/60000 (43%)]	Loss: 0.000664
# Train Epoch: 133 [51200/60000 (85%)]	Loss: 0.000668
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/133.pt
#
# Train Epoch: 134 [0/60000 (0%)]	Loss: 0.000906
# Train Epoch: 134 [25600/60000 (43%)]	Loss: 0.001561
# Train Epoch: 134 [51200/60000 (85%)]	Loss: 0.001159
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/134.pt
#
# Train Epoch: 135 [0/60000 (0%)]	Loss: 0.001092
# Train Epoch: 135 [25600/60000 (43%)]	Loss: 0.002372
# Train Epoch: 135 [51200/60000 (85%)]	Loss: 0.000752
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/135.pt
#
# Train Epoch: 136 [0/60000 (0%)]	Loss: 0.001112
# Train Epoch: 136 [25600/60000 (43%)]	Loss: 0.000853
# Train Epoch: 136 [51200/60000 (85%)]	Loss: 0.000722
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/136.pt
#
# Train Epoch: 137 [0/60000 (0%)]	Loss: 0.001081
# Train Epoch: 137 [25600/60000 (43%)]	Loss: 0.001254
# Train Epoch: 137 [51200/60000 (85%)]	Loss: 0.001006
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/137.pt
#
# Train Epoch: 138 [0/60000 (0%)]	Loss: 0.000616
# Train Epoch: 138 [25600/60000 (43%)]	Loss: 0.001121
# Train Epoch: 138 [51200/60000 (85%)]	Loss: 0.000677
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/138.pt
#
# Train Epoch: 139 [0/60000 (0%)]	Loss: 0.001854
# Train Epoch: 139 [25600/60000 (43%)]	Loss: 0.000946
# Train Epoch: 139 [51200/60000 (85%)]	Loss: 0.001090
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/139.pt
#
# Train Epoch: 140 [0/60000 (0%)]	Loss: 0.000715
# Train Epoch: 140 [25600/60000 (43%)]	Loss: 0.000841
# Train Epoch: 140 [51200/60000 (85%)]	Loss: 0.000663
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/140.pt
#
# Train Epoch: 141 [0/60000 (0%)]	Loss: 0.001163
# Train Epoch: 141 [25600/60000 (43%)]	Loss: 0.001130
# Train Epoch: 141 [51200/60000 (85%)]	Loss: 0.001337
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/141.pt
#
# Train Epoch: 142 [0/60000 (0%)]	Loss: 0.001456
# Train Epoch: 142 [25600/60000 (43%)]	Loss: 0.000960
# Train Epoch: 142 [51200/60000 (85%)]	Loss: 0.001569
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/142.pt
#
# Train Epoch: 143 [0/60000 (0%)]	Loss: 0.000629
# Train Epoch: 143 [25600/60000 (43%)]	Loss: 0.000564
# Train Epoch: 143 [51200/60000 (85%)]	Loss: 0.000695
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/143.pt
#
# Train Epoch: 144 [0/60000 (0%)]	Loss: 0.001208
# Train Epoch: 144 [25600/60000 (43%)]	Loss: 0.000832
# Train Epoch: 144 [51200/60000 (85%)]	Loss: 0.000728
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/144.pt
#
# Train Epoch: 145 [0/60000 (0%)]	Loss: 0.001548
# Train Epoch: 145 [25600/60000 (43%)]	Loss: 0.000735
# Train Epoch: 145 [51200/60000 (85%)]	Loss: 0.000387
#
# Test set: Average loss: 0.0001, Accuracy: 9816/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/145.pt
#
# Train Epoch: 146 [0/60000 (0%)]	Loss: 0.001013
# Train Epoch: 146 [25600/60000 (43%)]	Loss: 0.001048
# Train Epoch: 146 [51200/60000 (85%)]	Loss: 0.000974
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/146.pt
#
# Train Epoch: 147 [0/60000 (0%)]	Loss: 0.001248
# Train Epoch: 147 [25600/60000 (43%)]	Loss: 0.000974
# Train Epoch: 147 [51200/60000 (85%)]	Loss: 0.000481
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/147.pt
#
# Train Epoch: 148 [0/60000 (0%)]	Loss: 0.000679
# Train Epoch: 148 [25600/60000 (43%)]	Loss: 0.000739
# Train Epoch: 148 [51200/60000 (85%)]	Loss: 0.000657
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/148.pt
#
# Train Epoch: 149 [0/60000 (0%)]	Loss: 0.001152
# Train Epoch: 149 [25600/60000 (43%)]	Loss: 0.001069
# Train Epoch: 149 [51200/60000 (85%)]	Loss: 0.000927
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/149.pt
#
# Train Epoch: 150 [0/60000 (0%)]	Loss: 0.000540
# Train Epoch: 150 [25600/60000 (43%)]	Loss: 0.000529
# Train Epoch: 150 [51200/60000 (85%)]	Loss: 0.000755
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/150.pt
#
# Train Epoch: 151 [0/60000 (0%)]	Loss: 0.000883
# Train Epoch: 151 [25600/60000 (43%)]	Loss: 0.000902
# Train Epoch: 151 [51200/60000 (85%)]	Loss: 0.000875
#
# Test set: Average loss: 0.0001, Accuracy: 9814/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/151.pt
#
# Train Epoch: 152 [0/60000 (0%)]	Loss: 0.001059
# Train Epoch: 152 [25600/60000 (43%)]	Loss: 0.000605
# Train Epoch: 152 [51200/60000 (85%)]	Loss: 0.001363
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/152.pt
#
# Train Epoch: 153 [0/60000 (0%)]	Loss: 0.000826
# Train Epoch: 153 [25600/60000 (43%)]	Loss: 0.000725
# Train Epoch: 153 [51200/60000 (85%)]	Loss: 0.000985
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/153.pt
#
# Train Epoch: 154 [0/60000 (0%)]	Loss: 0.000775
# Train Epoch: 154 [25600/60000 (43%)]	Loss: 0.000426
# Train Epoch: 154 [51200/60000 (85%)]	Loss: 0.000756
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/154.pt
#
# Train Epoch: 155 [0/60000 (0%)]	Loss: 0.000616
# Train Epoch: 155 [25600/60000 (43%)]	Loss: 0.001304
# Train Epoch: 155 [51200/60000 (85%)]	Loss: 0.000551
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/155.pt
#
# Train Epoch: 156 [0/60000 (0%)]	Loss: 0.000736
# Train Epoch: 156 [25600/60000 (43%)]	Loss: 0.000608
# Train Epoch: 156 [51200/60000 (85%)]	Loss: 0.001111
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/156.pt
#
# Train Epoch: 157 [0/60000 (0%)]	Loss: 0.000621
# Train Epoch: 157 [25600/60000 (43%)]	Loss: 0.000481
# Train Epoch: 157 [51200/60000 (85%)]	Loss: 0.000555
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/157.pt
#
# Train Epoch: 158 [0/60000 (0%)]	Loss: 0.000983
# Train Epoch: 158 [25600/60000 (43%)]	Loss: 0.000968
# Train Epoch: 158 [51200/60000 (85%)]	Loss: 0.000662
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/158.pt
#
# Train Epoch: 159 [0/60000 (0%)]	Loss: 0.000933
# Train Epoch: 159 [25600/60000 (43%)]	Loss: 0.001011
# Train Epoch: 159 [51200/60000 (85%)]	Loss: 0.000859
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/159.pt
#
# Train Epoch: 160 [0/60000 (0%)]	Loss: 0.001243
# Train Epoch: 160 [25600/60000 (43%)]	Loss: 0.001133
# Train Epoch: 160 [51200/60000 (85%)]	Loss: 0.000670
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/160.pt
#
# Train Epoch: 161 [0/60000 (0%)]	Loss: 0.000746
# Train Epoch: 161 [25600/60000 (43%)]	Loss: 0.000964
# Train Epoch: 161 [51200/60000 (85%)]	Loss: 0.000936
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/161.pt
#
# Train Epoch: 162 [0/60000 (0%)]	Loss: 0.001156
# Train Epoch: 162 [25600/60000 (43%)]	Loss: 0.000979
# Train Epoch: 162 [51200/60000 (85%)]	Loss: 0.000746
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/162.pt
#
# Train Epoch: 163 [0/60000 (0%)]	Loss: 0.000575
# Train Epoch: 163 [25600/60000 (43%)]	Loss: 0.000639
# Train Epoch: 163 [51200/60000 (85%)]	Loss: 0.000757
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/163.pt
#
# Train Epoch: 164 [0/60000 (0%)]	Loss: 0.000921
# Train Epoch: 164 [25600/60000 (43%)]	Loss: 0.000765
# Train Epoch: 164 [51200/60000 (85%)]	Loss: 0.000618
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/164.pt
#
# Train Epoch: 165 [0/60000 (0%)]	Loss: 0.000952
# Train Epoch: 165 [25600/60000 (43%)]	Loss: 0.000546
# Train Epoch: 165 [51200/60000 (85%)]	Loss: 0.000684
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/165.pt
#
# Train Epoch: 166 [0/60000 (0%)]	Loss: 0.001158
# Train Epoch: 166 [25600/60000 (43%)]	Loss: 0.000720
# Train Epoch: 166 [51200/60000 (85%)]	Loss: 0.000631
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/166.pt
#
# Train Epoch: 167 [0/60000 (0%)]	Loss: 0.000924
# Train Epoch: 167 [25600/60000 (43%)]	Loss: 0.000867
# Train Epoch: 167 [51200/60000 (85%)]	Loss: 0.000968
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/167.pt
#
# Train Epoch: 168 [0/60000 (0%)]	Loss: 0.000755
# Train Epoch: 168 [25600/60000 (43%)]	Loss: 0.000954
# Train Epoch: 168 [51200/60000 (85%)]	Loss: 0.001161
#
# Test set: Average loss: 0.0001, Accuracy: 9815/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/168.pt
#
# Train Epoch: 169 [0/60000 (0%)]	Loss: 0.000689
# Train Epoch: 169 [25600/60000 (43%)]	Loss: 0.001193
# Train Epoch: 169 [51200/60000 (85%)]	Loss: 0.000353
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/169.pt
#
# Train Epoch: 170 [0/60000 (0%)]	Loss: 0.000949
# Train Epoch: 170 [25600/60000 (43%)]	Loss: 0.000887
# Train Epoch: 170 [51200/60000 (85%)]	Loss: 0.001020
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/170.pt
#
# Train Epoch: 171 [0/60000 (0%)]	Loss: 0.000619
# Train Epoch: 171 [25600/60000 (43%)]	Loss: 0.000629
# Train Epoch: 171 [51200/60000 (85%)]	Loss: 0.000646
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/171.pt
#
# Train Epoch: 172 [0/60000 (0%)]	Loss: 0.000577
# Train Epoch: 172 [25600/60000 (43%)]	Loss: 0.000759
# Train Epoch: 172 [51200/60000 (85%)]	Loss: 0.000786
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/172.pt
#
# Train Epoch: 173 [0/60000 (0%)]	Loss: 0.000428
# Train Epoch: 173 [25600/60000 (43%)]	Loss: 0.000636
# Train Epoch: 173 [51200/60000 (85%)]	Loss: 0.000363
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/173.pt
#
# Train Epoch: 174 [0/60000 (0%)]	Loss: 0.000739
# Train Epoch: 174 [25600/60000 (43%)]	Loss: 0.000321
# Train Epoch: 174 [51200/60000 (85%)]	Loss: 0.000501
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/174.pt
#
# Train Epoch: 175 [0/60000 (0%)]	Loss: 0.000543
# Train Epoch: 175 [25600/60000 (43%)]	Loss: 0.000568
# Train Epoch: 175 [51200/60000 (85%)]	Loss: 0.000982
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/175.pt
#
# Train Epoch: 176 [0/60000 (0%)]	Loss: 0.000462
# Train Epoch: 176 [25600/60000 (43%)]	Loss: 0.001328
# Train Epoch: 176 [51200/60000 (85%)]	Loss: 0.000582
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/176.pt
#
# Train Epoch: 177 [0/60000 (0%)]	Loss: 0.000581
# Train Epoch: 177 [25600/60000 (43%)]	Loss: 0.000609
# Train Epoch: 177 [51200/60000 (85%)]	Loss: 0.000401
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/177.pt
#
# Train Epoch: 178 [0/60000 (0%)]	Loss: 0.000404
# Train Epoch: 178 [25600/60000 (43%)]	Loss: 0.001054
# Train Epoch: 178 [51200/60000 (85%)]	Loss: 0.000611
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/178.pt
#
# Train Epoch: 179 [0/60000 (0%)]	Loss: 0.000511
# Train Epoch: 179 [25600/60000 (43%)]	Loss: 0.001018
# Train Epoch: 179 [51200/60000 (85%)]	Loss: 0.000473
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/179.pt
#
# Train Epoch: 180 [0/60000 (0%)]	Loss: 0.000758
# Train Epoch: 180 [25600/60000 (43%)]	Loss: 0.000368
# Train Epoch: 180 [51200/60000 (85%)]	Loss: 0.000813
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/180.pt
#
# Train Epoch: 181 [0/60000 (0%)]	Loss: 0.000728
# Train Epoch: 181 [25600/60000 (43%)]	Loss: 0.000820
# Train Epoch: 181 [51200/60000 (85%)]	Loss: 0.000816
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/181.pt
#
# Train Epoch: 182 [0/60000 (0%)]	Loss: 0.000528
# Train Epoch: 182 [25600/60000 (43%)]	Loss: 0.000860
# Train Epoch: 182 [51200/60000 (85%)]	Loss: 0.000313
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/182.pt
#
# Train Epoch: 183 [0/60000 (0%)]	Loss: 0.000649
# Train Epoch: 183 [25600/60000 (43%)]	Loss: 0.000677
# Train Epoch: 183 [51200/60000 (85%)]	Loss: 0.000502
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/183.pt
#
# Train Epoch: 184 [0/60000 (0%)]	Loss: 0.000628
# Train Epoch: 184 [25600/60000 (43%)]	Loss: 0.000876
# Train Epoch: 184 [51200/60000 (85%)]	Loss: 0.000905
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/184.pt
#
# Train Epoch: 185 [0/60000 (0%)]	Loss: 0.000405
# Train Epoch: 185 [25600/60000 (43%)]	Loss: 0.000855
# Train Epoch: 185 [51200/60000 (85%)]	Loss: 0.000948
#
# Test set: Average loss: 0.0001, Accuracy: 9824/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/185.pt
#
# Train Epoch: 186 [0/60000 (0%)]	Loss: 0.000490
# Train Epoch: 186 [25600/60000 (43%)]	Loss: 0.000460
# Train Epoch: 186 [51200/60000 (85%)]	Loss: 0.000634
#
# Test set: Average loss: 0.0001, Accuracy: 9824/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/186.pt
#
# Train Epoch: 187 [0/60000 (0%)]	Loss: 0.000473
# Train Epoch: 187 [25600/60000 (43%)]	Loss: 0.000601
# Train Epoch: 187 [51200/60000 (85%)]	Loss: 0.000594
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/187.pt
#
# Train Epoch: 188 [0/60000 (0%)]	Loss: 0.000712
# Train Epoch: 188 [25600/60000 (43%)]	Loss: 0.000485
# Train Epoch: 188 [51200/60000 (85%)]	Loss: 0.000941
#
# Test set: Average loss: 0.0001, Accuracy: 9819/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/188.pt
#
# Train Epoch: 189 [0/60000 (0%)]	Loss: 0.000691
# Train Epoch: 189 [25600/60000 (43%)]	Loss: 0.001034
# Train Epoch: 189 [51200/60000 (85%)]	Loss: 0.000757
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/189.pt
#
# Train Epoch: 190 [0/60000 (0%)]	Loss: 0.000387
# Train Epoch: 190 [25600/60000 (43%)]	Loss: 0.000688
# Train Epoch: 190 [51200/60000 (85%)]	Loss: 0.000347
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/190.pt
#
# Train Epoch: 191 [0/60000 (0%)]	Loss: 0.000503
# Train Epoch: 191 [25600/60000 (43%)]	Loss: 0.000541
# Train Epoch: 191 [51200/60000 (85%)]	Loss: 0.000471
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/191.pt
#
# Train Epoch: 192 [0/60000 (0%)]	Loss: 0.000425
# Train Epoch: 192 [25600/60000 (43%)]	Loss: 0.000657
# Train Epoch: 192 [51200/60000 (85%)]	Loss: 0.000547
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/192.pt
#
# Train Epoch: 193 [0/60000 (0%)]	Loss: 0.000460
# Train Epoch: 193 [25600/60000 (43%)]	Loss: 0.000481
# Train Epoch: 193 [51200/60000 (85%)]	Loss: 0.000532
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/193.pt
#
# Train Epoch: 194 [0/60000 (0%)]	Loss: 0.000501
# Train Epoch: 194 [25600/60000 (43%)]	Loss: 0.000453
# Train Epoch: 194 [51200/60000 (85%)]	Loss: 0.000823
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/194.pt
#
# Train Epoch: 195 [0/60000 (0%)]	Loss: 0.000489
# Train Epoch: 195 [25600/60000 (43%)]	Loss: 0.000712
# Train Epoch: 195 [51200/60000 (85%)]	Loss: 0.000910
#
# Test set: Average loss: 0.0001, Accuracy: 9817/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/195.pt
#
# Train Epoch: 196 [0/60000 (0%)]	Loss: 0.000778
# Train Epoch: 196 [25600/60000 (43%)]	Loss: 0.000441
# Train Epoch: 196 [51200/60000 (85%)]	Loss: 0.000620
#
# Test set: Average loss: 0.0001, Accuracy: 9821/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/196.pt
#
# Train Epoch: 197 [0/60000 (0%)]	Loss: 0.000684
# Train Epoch: 197 [25600/60000 (43%)]	Loss: 0.000339
# Train Epoch: 197 [51200/60000 (85%)]	Loss: 0.000547
#
# Test set: Average loss: 0.0001, Accuracy: 9818/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/197.pt
#
# Train Epoch: 198 [0/60000 (0%)]	Loss: 0.000675
# Train Epoch: 198 [25600/60000 (43%)]	Loss: 0.000335
# Train Epoch: 198 [51200/60000 (85%)]	Loss: 0.000827
#
# Test set: Average loss: 0.0001, Accuracy: 9822/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/198.pt
#
# Train Epoch: 199 [0/60000 (0%)]	Loss: 0.000441
# Train Epoch: 199 [25600/60000 (43%)]	Loss: 0.000291
# Train Epoch: 199 [51200/60000 (85%)]	Loss: 0.000404
#
# Test set: Average loss: 0.0001, Accuracy: 9820/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/199.pt
#
# Train Epoch: 200 [0/60000 (0%)]	Loss: 0.000562
# Train Epoch: 200 [25600/60000 (43%)]	Loss: 0.000670
# Train Epoch: 200 [51200/60000 (85%)]	Loss: 0.000323
#
# Test set: Average loss: 0.0001, Accuracy: 9823/10000 (98%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/200.pt
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/200.pt
